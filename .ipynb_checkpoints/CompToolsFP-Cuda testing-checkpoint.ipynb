# %%
import numpy as np
import pandas as pd
import scipy
import spacy
import sys
from collections import Counter
from time import time
import torch
from sklearn import model_selection
import math
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from sklearn.model_selection import KFold
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# data = pd.read_csv('articles1.csv')

# %%
# # Make a DataFrame with articles by our chosen authors
# # Include author names and article titles.

# # Make a list of the 10 chosen author names
# names = data.author.value_counts()[data.author.value_counts()>100][-30:].index.tolist()

# # DataFrame for articles of all chosen authors
# authors_data = pd.DataFrame()
# for name in names:
#     # Select each author's data
#     articles = data[data.author==name][:100][['title','content','author']]
#     # Append it to the DataFrame
#     authors_data = authors_data.append(articles)

# authors_data = authors_data.reset_index().drop('index',1)
    
# authors_data.head()

# %%
# # Look for duplicates
# print('Number of articles:',authors_data.shape[0])
# print('Unique articles:',len(np.unique(authors_data.index)))

# # Number of authors
# print('Unique authors:',len(np.unique(authors_data.author)))
# print('')
# print('Articles by author:\n')

# # Articles counts by author
# print(authors_data.author.value_counts())

# %%
# #!{sys.executable} -m spacy download en

# t0 = time()

# # Load spacy NLP object
# nlp = spacy.load("en_core_web_sm")
# # A list to store common words by all authors
# common_words = []

# # A dictionary to store the spacy_doc object of each author
# authors_docs = {}

# for name in names:
#     # Corpus is all the text written by that author
#     corpus = ""
#     # Grab all rows of current author, along the 'content' column
#     author_content = authors_data.loc[authors_data.author==name,'content']
    
#     # Merge all articles in to the author's corpus
#     for article in author_content:
#         corpus = corpus + article
#     # Let Spacy parse the author's body of text
#     doc = nlp(corpus)
    
#     # Store the doc in the dictionary
#     authors_docs[name] = doc
        
#     # Filter out punctuation and stop words.
#     lemmas = [token.lemma_ for token in doc
#                 if not token.is_punct and not token.is_stop]
        
#     # Return the most common words of that author's corpus.
#     bow = [item[0] for item in Counter(lemmas).most_common(1000)]
    
#     # Add them to the list of words by all authors.
#     for word in bow:
#         common_words.append(word)

# # Eliminate duplicates
# common_words = set(common_words)
    
# print('Total number of common words:',len(common_words))
# print("done in %0.3fs" % (time() - t0))

# %%
# # Let's see our 10 authors in the dictionary
# lengths = []
# for k,v in authors_docs.items():
#     print(k,'corpus contains',len(v),' words.')
#     lengths.append(len(v))

# %%
# # check for lower case words
# common_words = pd.Series(pd.DataFrame(columns=common_words).columns)
# print('Count of all common_words:',len(common_words))
# print('Count of lowercase common_words:',np.sum([word.islower() for word in common_words]))

# # Turn all common_words into lower case
# common_words = [word.lower() for word in common_words]
# print('Count of lowercase common_words (After Conversion):',np.sum([word.islower() for word in common_words]))


# # We must remove these in to avoid conflicts with existing features.
# if 'author' in common_words:
#     common_words.remove('author')
# if 'title' in common_words:
#     common_words.remove('title')
# if 'content' in common_words:
#     common_words.remove('content')

# %%
# # Count the number of times a common_word appears in each article
# # (about 3Hrs processing)

# bow_counts = pd.DataFrame()
# for name in names:
#     # Select X articles of that author
#     articles = authors_data.loc[authors_data.author==name,:][:50]
#     bow_counts = bow_counts.append(articles)
# bow_counts = bow_counts.reset_index().drop('index',1)

# # Use common_words as the columns of a temporary DataFrame
# df = pd.DataFrame(columns=common_words)

# # Join BOW features with the author's content
# bow_counts = bow_counts.join(df)

# # Initialize rows with zeroes
# bow_counts = bow_counts.loc[:,~bow_counts.columns.duplicated()].copy()
# bow_counts.loc[:,common_words] = 0

# # Fill the DataFrame with counts of each feature in each article
# t0 = time()
# for i, article in enumerate(bow_counts.content):
#     doc = nlp(article)
#     for token in doc:
#         if token.lemma_.lower() in common_words:
#             bow_counts.loc[i,token.lemma_.lower()] += 1
#     # Print a message every X articles
#     if i % 50 == 0:
#         if time()-t0 < 3600: # if less than an hour in seconds
#             print("Article ",i," done after ",(time()-t0)/60,' minutes.')
#         else:
#             print("Article ",i," done after ",(time()-t0)/60/60,' hours.')

# %%
# This saves the long-awaited data into a pickle file for easy recovery
#bow_counts.to_pickle('bow_counts')
# Read it back in with the following
bow_counts = pd.read_pickle('bow_counts')

# %%
y = bow_counts['author']
counter = 0
newy = np.zeros(len(y))
last = y[0]
for i in range(len(y)):
    if y[i] != last:
        counter+=1
    newy[i] = counter
    last = y[i]
X = bow_counts.drop(['content','author','title'], 1)
X = X.loc[:,~X.columns.duplicated()].copy()
X = X.to_numpy()
N, M = X.shape
import torch.nn as nn
#X = scipy.stats.zscore(X)
n_hidden_units = 2     # number of hidden units
n_replicates = 1        # number of networks trained in each k-fold
max_iter = 10000         # stop criterion 2 (max epochs in training)

# K-fold crossvalidation
#K = 3                   # only five folds to speed up this example
#CV = model_selection.KFold(K, shuffle=True)
model = torch.nn.Sequential(
                    torch.nn.Linear(M, n_hidden_units), #M features to H hiden units
                    torch.nn.Tanh(),   # 1st transfer function,
                    torch.nn.Linear(n_hidden_units, 1), # H hidden units to 1 output neuron
                    torch.nn.Sigmoid(), # final tranfer function
                    )
#loss_fn = torch.nn.MSELoss
# class Net(nn.Module):
#     def __init__(self,D_in,H,D_out):
#         super(Net,self).__init__()
#         self.linear1=nn.Linear(D_in,H)
#         self.linear2=nn.Linear(H,D_out)

        
#     def forward(self,x):
#         x=torch.sigmoid(self.linear1(x))  
#         x=self.linear2(x)
#         return x
# model=Net(M,25,30)
class Net(nn.Module):
    def __init__(self,D_in,H,H2,H3,D_out):
        super(Net,self).__init__()
        self.linear1=nn.Linear(D_in,H)
        self.linear2=nn.Linear(H,H2)
        #self.linear3=nn.Linear(H2,D_out)
        self.linear3=nn.Linear(H2,H3)
        self.linear4=nn.Linear(H3,D_out)
        
    def forward(self,x):
        x=F.relu(self.linear1(x))
        x=F.relu(self.linear2(x))
        x=F.relu(self.linear3(x))  
        #x=self.linear3(x)
        x=self.linear4(x)
        return x
#model=Net(M,300,150,30)
loss_fn = torch.nn.CrossEntropyLoss()
# Out:
# C:\Users\penna\AppData\Local\Temp\ipykernel_21672\4032825044.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = bow_counts.drop(['content','author','title'], 1)

# %%
batch_size=128
k=20
splits=KFold(n_splits=k,shuffle=True,random_state=42)

# %%
#dataset = np.column_stack((X,newy))
X = X.astype('float32')
class Data(Dataset):
    def __init__(self):
        self.x=torch.from_numpy(X)
        self.y=torch.from_numpy(newy)
        self.len=self.x.shape[0]
    def __getitem__(self,index):      
        return self.x[index], self.y[index]
    def __len__(self):
        return self.len
dataset=Data()

# %%
def train_epoch(model,device,dataloader,loss_fn,optimizer):
    train_loss,train_correct=0.0,0
    model.train()
    #for images, labels in dataloader:
    for inputs,labels in dataloader:
        inputs,labels = inputs.to(device),labels.to(device)
        optimizer.zero_grad()
        output = model(inputs)
        loss = loss_fn(output,labels.long())
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)
        scores, predictions = torch.max(output.data, 1)
        train_correct += (predictions == labels).sum().item()

    return train_loss,train_correct
  
def valid_epoch(model,device,dataloader,loss_fn):
    valid_loss, val_correct = 0.0, 0
    model.eval()
    for inputs, labels in dataloader:

        inputs,labels = inputs.to(device),labels.to(device)
        output = model(inputs)
        loss=loss_fn(output,labels.long())
        valid_loss+=loss.item()*inputs.size(0)
        scores, predictions = torch.max(output.data,1)
        val_correct+=(predictions == labels).sum().item()
    return valid_loss,val_correct

# %%
H1 = round(math.sqrt(M * 30))
H2 = round(H1/2)
H3 = round(H2/2)
foldperf={}
num_epochs=10
for fold, (train_idx,val_idx) in enumerate(splits.split(np.arange(len(dataset)))):

    print('Fold {}'.format(fold + 1))

    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(val_idx)
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_sampler)
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    model = Net(M,H1,H2,H3,30)
    model.to(device)
    learning_rate=0.0004
    #optimizer=torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    history = {'train_loss': [], 'test_loss': [],'train_acc':[],'test_acc':[]}

    for epoch in range(num_epochs):
        train_loss, train_correct=train_epoch(model,device,train_loader,loss_fn,optimizer)
        test_loss, test_correct=valid_epoch(model,device,test_loader,loss_fn)

        train_loss = train_loss / len(train_loader.sampler)
        train_acc = train_correct / len(train_loader.sampler) * 100
        test_loss = test_loss / len(test_loader.sampler)
        test_acc = test_correct / len(test_loader.sampler) * 100

        print("Epoch:{}/{} AVG Training Loss:{:.3f} AVG Test Loss:{:.3f} AVG Training Acc {:.2f} % AVG Test Acc {:.2f} %".format(epoch + 1,
                                                                                                             num_epochs,
                                                                                                             train_loss,
                                                                                                             test_loss,
                                                                                                             train_acc,
                                                                                                             test_acc))
        history['train_loss'].append(train_loss)
        history['test_loss'].append(test_loss)
        history['train_acc'].append(train_acc)
        history['test_acc'].append(test_acc)

    foldperf['fold{}'.format(fold+1)] = history
# Out:
# Fold 1
# Epoch:1/10 AVG Training Loss:3.336 AVG Test Loss:3.251 AVG Training Acc 9.33 % AVG Test Acc 10.67 %
# Epoch:2/10 AVG Training Loss:2.998 AVG Test Loss:2.903 AVG Training Acc 31.37 % AVG Test Acc 29.33 %
# Epoch:3/10 AVG Training Loss:2.459 AVG Test Loss:2.399 AVG Training Acc 48.63 % AVG Test Acc 41.33 %
# Epoch:4/10 AVG Training Loss:1.835 AVG Test Loss:1.954 AVG Training Acc 72.14 % AVG Test Acc 60.00 %
# Epoch:5/10 AVG Training Loss:1.275 AVG Test Loss:1.587 AVG Training Acc 84.84 % AVG Test Acc 70.67 %
# Epoch:6/10 AVG Training Loss:0.881 AVG Test Loss:1.420 AVG Training Acc 88.63 % AVG Test Acc 69.33 %
# Epoch:7/10 AVG Training Loss:0.608 AVG Test Loss:1.335 AVG Training Acc 92.49 % AVG Test Acc 66.67 %
# Epoch:8/10 AVG Training Loss:0.419 AVG Test Loss:1.188 AVG Training Acc 95.58 % AVG Test Acc 70.67 %
# Epoch:9/10 AVG Training Loss:0.292 AVG Test Loss:1.131 AVG Training Acc 97.75 % AVG Test Acc 70.67 %
# Epoch:10/10 AVG Training Loss:0.210 AVG Test Loss:1.100 AVG Training Acc 99.02 % AVG Test Acc 77.33 %
# Fold 2
# Epoch:1/10 AVG Training Loss:3.343 AVG Test Loss:3.196 AVG Training Acc 8.91 % AVG Test Acc 16.00 %
# Epoch:2/10 AVG Training Loss:3.029 AVG Test Loss:2.821 AVG Training Acc 25.47 % AVG Test Acc 32.00 %
# Epoch:3/10 AVG Training Loss:2.523 AVG Test Loss:2.326 AVG Training Acc 44.56 % AVG Test Acc 49.33 %
# Epoch:4/10 AVG Training Loss:1.884 AVG Test Loss:1.915 AVG Training Acc 68.42 % AVG Test Acc 61.33 %
# Epoch:5/10 AVG Training Loss:1.314 AVG Test Loss:1.583 AVG Training Acc 79.51 % AVG Test Acc 70.67 %
# Epoch:6/10 AVG Training Loss:0.890 AVG Test Loss:1.469 AVG Training Acc 90.04 % AVG Test Acc 66.67 %
# Epoch:7/10 AVG Training Loss:0.610 AVG Test Loss:1.291 AVG Training Acc 94.25 % AVG Test Acc 68.00 %
# Epoch:8/10 AVG Training Loss:0.417 AVG Test Loss:1.237 AVG Training Acc 97.47 % AVG Test Acc 73.33 %
# Epoch:9/10 AVG Training Loss:0.289 AVG Test Loss:1.357 AVG Training Acc 98.81 % AVG Test Acc 73.33 %
# Epoch:10/10 AVG Training Loss:0.213 AVG Test Loss:1.237 AVG Training Acc 99.16 % AVG Test Acc 72.00 %
# Fold 3
# Epoch:1/10 AVG Training Loss:3.365 AVG Test Loss:3.282 AVG Training Acc 7.23 % AVG Test Acc 22.67 %
# Epoch:2/10 AVG Training Loss:3.072 AVG Test Loss:2.901 AVG Training Acc 25.05 % AVG Test Acc 38.67 %
# Epoch:3/10 AVG Training Loss:2.505 AVG Test Loss:2.338 AVG Training Acc 46.32 % AVG Test Acc 48.00 %
# Epoch:4/10 AVG Training Loss:1.853 AVG Test Loss:1.753 AVG Training Acc 65.89 % AVG Test Acc 61.33 %
# Epoch:5/10 AVG Training Loss:1.274 AVG Test Loss:1.385 AVG Training Acc 81.89 % AVG Test Acc 68.00 %
# Epoch:6/10 AVG Training Loss:0.856 AVG Test Loss:1.149 AVG Training Acc 89.82 % AVG Test Acc 72.00 %
# Epoch:7/10 AVG Training Loss:0.569 AVG Test Loss:1.001 AVG Training Acc 94.46 % AVG Test Acc 76.00 %
# Epoch:8/10 AVG Training Loss:0.394 AVG Test Loss:0.976 AVG Training Acc 96.70 % AVG Test Acc 68.00 %
# Epoch:9/10 AVG Training Loss:0.284 AVG Test Loss:0.951 AVG Training Acc 97.89 % AVG Test Acc 73.33 %
# Epoch:10/10 AVG Training Loss:0.208 AVG Test Loss:0.989 AVG Training Acc 98.60 % AVG Test Acc 73.33 %
# Fold 4
# Epoch:1/10 AVG Training Loss:3.345 AVG Test Loss:3.261 AVG Training Acc 14.67 % AVG Test Acc 21.33 %
# Epoch:2/10 AVG Training Loss:3.008 AVG Test Loss:2.961 AVG Training Acc 28.00 % AVG Test Acc 24.00 %
# Epoch:3/10 AVG Training Loss:2.443 AVG Test Loss:2.459 AVG Training Acc 49.05 % AVG Test Acc 38.67 %
# Epoch:4/10 AVG Training Loss:1.794 AVG Test Loss:1.954 AVG Training Acc 68.77 % AVG Test Acc 56.00 %
# Epoch:5/10 AVG Training Loss:1.226 AVG Test Loss:1.625 AVG Training Acc 87.58 % AVG Test Acc 61.33 %
# Epoch:6/10 AVG Training Loss:0.824 AVG Test Loss:1.485 AVG Training Acc 90.95 % AVG Test Acc 61.33 %
# Epoch:7/10 AVG Training Loss:0.561 AVG Test Loss:1.319 AVG Training Acc 93.89 % AVG Test Acc 65.33 %
# Epoch:8/10 AVG Training Loss:0.391 AVG Test Loss:1.246 AVG Training Acc 96.21 % AVG Test Acc 69.33 %
# Epoch:9/10 AVG Training Loss:0.270 AVG Test Loss:1.198 AVG Training Acc 98.18 % AVG Test Acc 61.33 %
# Epoch:10/10 AVG Training Loss:0.197 AVG Test Loss:1.173 AVG Training Acc 99.23 % AVG Test Acc 66.67 %
# Fold 5
# Epoch:1/10 AVG Training Loss:3.359 AVG Test Loss:3.267 AVG Training Acc 6.04 % AVG Test Acc 9.33 %
# Epoch:2/10 AVG Training Loss:3.085 AVG Test Loss:2.875 AVG Training Acc 14.74 % AVG Test Acc 25.33 %
# Epoch:3/10 AVG Training Loss:2.595 AVG Test Loss:2.285 AVG Training Acc 41.47 % AVG Test Acc 53.33 %
# Epoch:4/10 AVG Training Loss:2.006 AVG Test Loss:1.773 AVG Training Acc 60.77 % AVG Test Acc 68.00 %
# Epoch:5/10 AVG Training Loss:1.437 AVG Test Loss:1.445 AVG Training Acc 81.19 % AVG Test Acc 72.00 %
# Epoch:6/10 AVG Training Loss:0.998 AVG Test Loss:1.193 AVG Training Acc 86.32 % AVG Test Acc 68.00 %
# Epoch:7/10 AVG Training Loss:0.703 AVG Test Loss:1.038 AVG Training Acc 93.40 % AVG Test Acc 74.67 %
# Epoch:8/10 AVG Training Loss:0.516 AVG Test Loss:0.927 AVG Training Acc 94.32 % AVG Test Acc 74.67 %
# Epoch:9/10 AVG Training Loss:0.351 AVG Test Loss:0.905 AVG Training Acc 98.32 % AVG Test Acc 76.00 %
# Epoch:10/10 AVG Training Loss:0.259 AVG Test Loss:0.820 AVG Training Acc 98.88 % AVG Test Acc 80.00 %
# Fold 6
# Epoch:1/10 AVG Training Loss:3.360 AVG Test Loss:3.287 AVG Training Acc 5.40 % AVG Test Acc 6.67 %
# Epoch:2/10 AVG Training Loss:3.072 AVG Test Loss:2.928 AVG Training Acc 23.44 % AVG Test Acc 32.00 %
# Epoch:3/10 AVG Training Loss:2.554 AVG Test Loss:2.406 AVG Training Acc 46.32 % AVG Test Acc 42.67 %
# Epoch:4/10 AVG Training Loss:1.942 AVG Test Loss:1.907 AVG Training Acc 64.14 % AVG Test Acc 61.33 %
# Epoch:5/10 AVG Training Loss:1.349 AVG Test Loss:1.519 AVG Training Acc 83.23 % AVG Test Acc 65.33 %
# Epoch:6/10 AVG Training Loss:0.919 AVG Test Loss:1.283 AVG Training Acc 89.40 % AVG Test Acc 68.00 %
# Epoch:7/10 AVG Training Loss:0.614 AVG Test Loss:1.204 AVG Training Acc 93.47 % AVG Test Acc 65.33 %
# Epoch:8/10 AVG Training Loss:0.454 AVG Test Loss:1.104 AVG Training Acc 94.67 % AVG Test Acc 69.33 %
# Epoch:9/10 AVG Training Loss:0.310 AVG Test Loss:1.120 AVG Training Acc 97.82 % AVG Test Acc 66.67 %
# Epoch:10/10 AVG Training Loss:0.232 AVG Test Loss:1.153 AVG Training Acc 98.39 % AVG Test Acc 66.67 %
# Fold 7
# Epoch:1/10 AVG Training Loss:3.339 AVG Test Loss:3.228 AVG Training Acc 12.84 % AVG Test Acc 21.33 %
# Epoch:2/10 AVG Training Loss:2.991 AVG Test Loss:2.839 AVG Training Acc 32.00 % AVG Test Acc 33.33 %
# Epoch:3/10 AVG Training Loss:2.431 AVG Test Loss:2.311 AVG Training Acc 48.84 % AVG Test Acc 49.33 %
# Epoch:4/10 AVG Training Loss:1.832 AVG Test Loss:1.903 AVG Training Acc 69.82 % AVG Test Acc 57.33 %
# Epoch:5/10 AVG Training Loss:1.305 AVG Test Loss:1.566 AVG Training Acc 83.58 % AVG Test Acc 60.00 %
# Epoch:6/10 AVG Training Loss:0.910 AVG Test Loss:1.308 AVG Training Acc 89.33 % AVG Test Acc 66.67 %
# Epoch:7/10 AVG Training Loss:0.644 AVG Test Loss:1.195 AVG Training Acc 92.91 % AVG Test Acc 69.33 %
# Epoch:8/10 AVG Training Loss:0.451 AVG Test Loss:1.086 AVG Training Acc 95.86 % AVG Test Acc 66.67 %
# Epoch:9/10 AVG Training Loss:0.326 AVG Test Loss:1.050 AVG Training Acc 97.33 % AVG Test Acc 66.67 %
# Epoch:10/10 AVG Training Loss:0.238 AVG Test Loss:1.038 AVG Training Acc 98.60 % AVG Test Acc 66.67 %
# Fold 8
# Epoch:1/10 AVG Training Loss:3.354 AVG Test Loss:3.281 AVG Training Acc 11.44 % AVG Test Acc 24.00 %
# Epoch:2/10 AVG Training Loss:3.069 AVG Test Loss:2.974 AVG Training Acc 30.95 % AVG Test Acc 25.33 %
# Epoch:3/10 AVG Training Loss:2.512 AVG Test Loss:2.500 AVG Training Acc 47.72 % AVG Test Acc 37.33 %
# Epoch:4/10 AVG Training Loss:1.872 AVG Test Loss:2.015 AVG Training Acc 68.91 % AVG Test Acc 54.67 %
# Epoch:5/10 AVG Training Loss:1.311 AVG Test Loss:1.661 AVG Training Acc 83.93 % AVG Test Acc 57.33 %
# Epoch:6/10 AVG Training Loss:0.898 AVG Test Loss:1.372 AVG Training Acc 89.26 % AVG Test Acc 65.33 %
# Epoch:7/10 AVG Training Loss:0.606 AVG Test Loss:1.226 AVG Training Acc 94.18 % AVG Test Acc 68.00 %
# Epoch:8/10 AVG Training Loss:0.429 AVG Test Loss:1.092 AVG Training Acc 96.07 % AVG Test Acc 66.67 %
# Epoch:9/10 AVG Training Loss:0.307 AVG Test Loss:1.056 AVG Training Acc 97.75 % AVG Test Acc 73.33 %
# Epoch:10/10 AVG Training Loss:0.216 AVG Test Loss:1.012 AVG Training Acc 98.74 % AVG Test Acc 72.00 %
# Fold 9
# Epoch:1/10 AVG Training Loss:3.350 AVG Test Loss:3.240 AVG Training Acc 10.18 % AVG Test Acc 17.33 %
# Epoch:2/10 AVG Training Loss:3.041 AVG Test Loss:2.836 AVG Training Acc 30.60 % AVG Test Acc 30.67 %
# Epoch:3/10 AVG Training Loss:2.514 AVG Test Loss:2.394 AVG Training Acc 47.23 % AVG Test Acc 46.67 %
# Epoch:4/10 AVG Training Loss:1.942 AVG Test Loss:2.066 AVG Training Acc 65.96 % AVG Test Acc 48.00 %
# Epoch:5/10 AVG Training Loss:1.398 AVG Test Loss:1.691 AVG Training Acc 81.12 % AVG Test Acc 60.00 %
# Epoch:6/10 AVG Training Loss:0.969 AVG Test Loss:1.399 AVG Training Acc 87.72 % AVG Test Acc 62.67 %
# Epoch:7/10 AVG Training Loss:0.666 AVG Test Loss:1.319 AVG Training Acc 94.04 % AVG Test Acc 58.67 %
# Epoch:8/10 AVG Training Loss:0.474 AVG Test Loss:1.146 AVG Training Acc 94.60 % AVG Test Acc 65.33 %
# Epoch:9/10 AVG Training Loss:0.334 AVG Test Loss:1.339 AVG Training Acc 97.75 % AVG Test Acc 57.33 %
# Epoch:10/10 AVG Training Loss:0.245 AVG Test Loss:1.165 AVG Training Acc 98.46 % AVG Test Acc 58.67 %
# Fold 10
# Epoch:1/10 AVG Training Loss:3.337 AVG Test Loss:3.241 AVG Training Acc 9.40 % AVG Test Acc 13.33 %
# Epoch:2/10 AVG Training Loss:2.970 AVG Test Loss:2.915 AVG Training Acc 25.61 % AVG Test Acc 32.00 %
# Epoch:3/10 AVG Training Loss:2.378 AVG Test Loss:2.432 AVG Training Acc 53.61 % AVG Test Acc 44.00 %
# Epoch:4/10 AVG Training Loss:1.744 AVG Test Loss:2.068 AVG Training Acc 70.67 % AVG Test Acc 52.00 %
# Epoch:5/10 AVG Training Loss:1.230 AVG Test Loss:1.549 AVG Training Acc 81.40 % AVG Test Acc 73.33 %
# Epoch:6/10 AVG Training Loss:0.844 AVG Test Loss:1.323 AVG Training Acc 90.39 % AVG Test Acc 68.00 %
# Epoch:7/10 AVG Training Loss:0.571 AVG Test Loss:1.358 AVG Training Acc 94.11 % AVG Test Acc 66.67 %
# Epoch:8/10 AVG Training Loss:0.401 AVG Test Loss:1.110 AVG Training Acc 95.93 % AVG Test Acc 70.67 %
# Epoch:9/10 AVG Training Loss:0.289 AVG Test Loss:1.258 AVG Training Acc 97.68 % AVG Test Acc 65.33 %
# Epoch:10/10 AVG Training Loss:0.201 AVG Test Loss:1.014 AVG Training Acc 98.74 % AVG Test Acc 73.33 %
# Fold 11
# Epoch:1/10 AVG Training Loss:3.367 AVG Test Loss:3.286 AVG Training Acc 9.05 % AVG Test Acc 28.00 %
# Epoch:2/10 AVG Training Loss:3.088 AVG Test Loss:2.955 AVG Training Acc 29.61 % AVG Test Acc 33.33 %
# Epoch:3/10 AVG Training Loss:2.554 AVG Test Loss:2.435 AVG Training Acc 47.23 % AVG Test Acc 37.33 %
# Epoch:4/10 AVG Training Loss:1.886 AVG Test Loss:1.978 AVG Training Acc 70.04 % AVG Test Acc 50.67 %
# Epoch:5/10 AVG Training Loss:1.314 AVG Test Loss:1.724 AVG Training Acc 82.11 % AVG Test Acc 46.67 %
# Epoch:6/10 AVG Training Loss:0.892 AVG Test Loss:1.448 AVG Training Acc 89.96 % AVG Test Acc 61.33 %
# Epoch:7/10 AVG Training Loss:0.603 AVG Test Loss:1.347 AVG Training Acc 93.96 % AVG Test Acc 62.67 %
# Epoch:8/10 AVG Training Loss:0.418 AVG Test Loss:1.267 AVG Training Acc 97.19 % AVG Test Acc 65.33 %
# Epoch:9/10 AVG Training Loss:0.291 AVG Test Loss:1.334 AVG Training Acc 97.47 % AVG Test Acc 64.00 %
# Epoch:10/10 AVG Training Loss:0.204 AVG Test Loss:1.296 AVG Training Acc 98.67 % AVG Test Acc 65.33 %
# Fold 12
# Epoch:1/10 AVG Training Loss:3.340 AVG Test Loss:3.193 AVG Training Acc 8.42 % AVG Test Acc 17.33 %
# Epoch:2/10 AVG Training Loss:2.995 AVG Test Loss:2.794 AVG Training Acc 23.51 % AVG Test Acc 28.00 %
# Epoch:3/10 AVG Training Loss:2.442 AVG Test Loss:2.243 AVG Training Acc 43.51 % AVG Test Acc 38.67 %
# Epoch:4/10 AVG Training Loss:1.814 AVG Test Loss:1.702 AVG Training Acc 69.61 % AVG Test Acc 64.00 %
# Epoch:5/10 AVG Training Loss:1.267 AVG Test Loss:1.373 AVG Training Acc 84.49 % AVG Test Acc 64.00 %
# Epoch:6/10 AVG Training Loss:0.865 AVG Test Loss:1.193 AVG Training Acc 89.12 % AVG Test Acc 64.00 %
# Epoch:7/10 AVG Training Loss:0.609 AVG Test Loss:1.051 AVG Training Acc 93.05 % AVG Test Acc 62.67 %
# Epoch:8/10 AVG Training Loss:0.428 AVG Test Loss:1.039 AVG Training Acc 95.93 % AVG Test Acc 62.67 %
# Epoch:9/10 AVG Training Loss:0.302 AVG Test Loss:0.934 AVG Training Acc 97.68 % AVG Test Acc 68.00 %
# Epoch:10/10 AVG Training Loss:0.213 AVG Test Loss:0.894 AVG Training Acc 99.16 % AVG Test Acc 68.00 %
# Fold 13
# Epoch:1/10 AVG Training Loss:3.359 AVG Test Loss:3.229 AVG Training Acc 8.98 % AVG Test Acc 25.33 %
# Epoch:2/10 AVG Training Loss:3.077 AVG Test Loss:2.904 AVG Training Acc 26.18 % AVG Test Acc 33.33 %
# Epoch:3/10 AVG Training Loss:2.588 AVG Test Loss:2.481 AVG Training Acc 47.93 % AVG Test Acc 44.00 %
# Epoch:4/10 AVG Training Loss:2.002 AVG Test Loss:1.946 AVG Training Acc 64.56 % AVG Test Acc 66.67 %
# Epoch:5/10 AVG Training Loss:1.417 AVG Test Loss:1.541 AVG Training Acc 83.72 % AVG Test Acc 72.00 %
# Epoch:6/10 AVG Training Loss:0.956 AVG Test Loss:1.276 AVG Training Acc 90.11 % AVG Test Acc 68.00 %
# Epoch:7/10 AVG Training Loss:0.640 AVG Test Loss:1.081 AVG Training Acc 94.25 % AVG Test Acc 72.00 %
# Epoch:8/10 AVG Training Loss:0.432 AVG Test Loss:0.933 AVG Training Acc 96.84 % AVG Test Acc 73.33 %
# Epoch:9/10 AVG Training Loss:0.289 AVG Test Loss:0.852 AVG Training Acc 98.46 % AVG Test Acc 77.33 %
# Epoch:10/10 AVG Training Loss:0.204 AVG Test Loss:0.832 AVG Training Acc 99.02 % AVG Test Acc 73.33 %
# Fold 14
# Epoch:1/10 AVG Training Loss:3.351 AVG Test Loss:3.278 AVG Training Acc 5.89 % AVG Test Acc 14.67 %
# Epoch:2/10 AVG Training Loss:3.054 AVG Test Loss:2.957 AVG Training Acc 21.75 % AVG Test Acc 24.00 %
# Epoch:3/10 AVG Training Loss:2.512 AVG Test Loss:2.491 AVG Training Acc 47.30 % AVG Test Acc 42.67 %
# Epoch:4/10 AVG Training Loss:1.824 AVG Test Loss:1.985 AVG Training Acc 67.09 % AVG Test Acc 54.67 %
# Epoch:5/10 AVG Training Loss:1.230 AVG Test Loss:1.590 AVG Training Acc 85.19 % AVG Test Acc 58.67 %
# Epoch:6/10 AVG Training Loss:0.826 AVG Test Loss:1.343 AVG Training Acc 88.42 % AVG Test Acc 62.67 %
# Epoch:7/10 AVG Training Loss:0.568 AVG Test Loss:1.327 AVG Training Acc 93.96 % AVG Test Acc 61.33 %
# Epoch:8/10 AVG Training Loss:0.390 AVG Test Loss:1.199 AVG Training Acc 95.65 % AVG Test Acc 61.33 %
# Epoch:9/10 AVG Training Loss:0.277 AVG Test Loss:1.039 AVG Training Acc 98.25 % AVG Test Acc 66.67 %
# Epoch:10/10 AVG Training Loss:0.194 AVG Test Loss:1.074 AVG Training Acc 98.88 % AVG Test Acc 65.33 %
# Fold 15
# Epoch:1/10 AVG Training Loss:3.352 AVG Test Loss:3.228 AVG Training Acc 11.02 % AVG Test Acc 24.00 %
# Epoch:2/10 AVG Training Loss:3.022 AVG Test Loss:2.785 AVG Training Acc 32.28 % AVG Test Acc 34.67 %
# Epoch:3/10 AVG Training Loss:2.440 AVG Test Loss:2.302 AVG Training Acc 46.25 % AVG Test Acc 49.33 %
# Epoch:4/10 AVG Training Loss:1.805 AVG Test Loss:1.800 AVG Training Acc 64.70 % AVG Test Acc 62.67 %
# Epoch:5/10 AVG Training Loss:1.234 AVG Test Loss:1.432 AVG Training Acc 83.02 % AVG Test Acc 61.33 %
# Epoch:6/10 AVG Training Loss:0.842 AVG Test Loss:1.229 AVG Training Acc 88.70 % AVG Test Acc 64.00 %
# Epoch:7/10 AVG Training Loss:0.589 AVG Test Loss:1.020 AVG Training Acc 92.84 % AVG Test Acc 66.67 %
# Epoch:8/10 AVG Training Loss:0.404 AVG Test Loss:1.094 AVG Training Acc 95.86 % AVG Test Acc 64.00 %
# Epoch:9/10 AVG Training Loss:0.283 AVG Test Loss:0.986 AVG Training Acc 98.18 % AVG Test Acc 68.00 %
# Epoch:10/10 AVG Training Loss:0.203 AVG Test Loss:1.039 AVG Training Acc 99.23 % AVG Test Acc 69.33 %
# Fold 16
# Epoch:1/10 AVG Training Loss:3.347 AVG Test Loss:3.193 AVG Training Acc 11.86 % AVG Test Acc 29.33 %
# Epoch:2/10 AVG Training Loss:3.026 AVG Test Loss:2.774 AVG Training Acc 30.04 % AVG Test Acc 36.00 %
# Epoch:3/10 AVG Training Loss:2.457 AVG Test Loss:2.216 AVG Training Acc 46.74 % AVG Test Acc 45.33 %
# Epoch:4/10 AVG Training Loss:1.795 AVG Test Loss:1.850 AVG Training Acc 70.88 % AVG Test Acc 50.67 %
# Epoch:5/10 AVG Training Loss:1.253 AVG Test Loss:1.568 AVG Training Acc 80.98 % AVG Test Acc 62.67 %
# Epoch:6/10 AVG Training Loss:0.866 AVG Test Loss:1.373 AVG Training Acc 87.79 % AVG Test Acc 60.00 %
# Epoch:7/10 AVG Training Loss:0.587 AVG Test Loss:1.175 AVG Training Acc 94.04 % AVG Test Acc 70.67 %
# Epoch:8/10 AVG Training Loss:0.409 AVG Test Loss:1.120 AVG Training Acc 96.70 % AVG Test Acc 72.00 %
# Epoch:9/10 AVG Training Loss:0.306 AVG Test Loss:1.089 AVG Training Acc 96.56 % AVG Test Acc 72.00 %
# Epoch:10/10 AVG Training Loss:0.217 AVG Test Loss:1.083 AVG Training Acc 98.74 % AVG Test Acc 72.00 %
# Fold 17
# Epoch:1/10 AVG Training Loss:3.348 AVG Test Loss:3.200 AVG Training Acc 9.26 % AVG Test Acc 22.67 %
# Epoch:2/10 AVG Training Loss:3.015 AVG Test Loss:2.754 AVG Training Acc 31.16 % AVG Test Acc 41.33 %
# Epoch:3/10 AVG Training Loss:2.473 AVG Test Loss:2.267 AVG Training Acc 50.25 % AVG Test Acc 46.67 %
# Epoch:4/10 AVG Training Loss:1.847 AVG Test Loss:1.730 AVG Training Acc 66.04 % AVG Test Acc 57.33 %
# Epoch:5/10 AVG Training Loss:1.268 AVG Test Loss:1.408 AVG Training Acc 86.88 % AVG Test Acc 54.67 %
# Epoch:6/10 AVG Training Loss:0.859 AVG Test Loss:1.272 AVG Training Acc 91.44 % AVG Test Acc 62.67 %
# Epoch:7/10 AVG Training Loss:0.569 AVG Test Loss:1.188 AVG Training Acc 95.09 % AVG Test Acc 58.67 %
# Epoch:8/10 AVG Training Loss:0.382 AVG Test Loss:1.173 AVG Training Acc 97.47 % AVG Test Acc 62.67 %
# Epoch:9/10 AVG Training Loss:0.274 AVG Test Loss:1.235 AVG Training Acc 97.96 % AVG Test Acc 60.00 %
# Epoch:10/10 AVG Training Loss:0.199 AVG Test Loss:1.124 AVG Training Acc 98.53 % AVG Test Acc 62.67 %
# Fold 18
# Epoch:1/10 AVG Training Loss:3.354 AVG Test Loss:3.264 AVG Training Acc 6.81 % AVG Test Acc 10.67 %
# Epoch:2/10 AVG Training Loss:3.044 AVG Test Loss:2.977 AVG Training Acc 20.07 % AVG Test Acc 25.33 %
# Epoch:3/10 AVG Training Loss:2.509 AVG Test Loss:2.547 AVG Training Acc 48.56 % AVG Test Acc 48.00 %
# Epoch:4/10 AVG Training Loss:1.856 AVG Test Loss:2.117 AVG Training Acc 70.39 % AVG Test Acc 57.33 %
# Epoch:5/10 AVG Training Loss:1.305 AVG Test Loss:1.859 AVG Training Acc 83.37 % AVG Test Acc 60.00 %
# Epoch:6/10 AVG Training Loss:0.904 AVG Test Loss:1.709 AVG Training Acc 87.65 % AVG Test Acc 58.67 %
# Epoch:7/10 AVG Training Loss:0.613 AVG Test Loss:1.554 AVG Training Acc 94.04 % AVG Test Acc 65.33 %
# Epoch:8/10 AVG Training Loss:0.422 AVG Test Loss:1.514 AVG Training Acc 96.63 % AVG Test Acc 58.67 %
# Epoch:9/10 AVG Training Loss:0.301 AVG Test Loss:1.538 AVG Training Acc 97.82 % AVG Test Acc 65.33 %
# Epoch:10/10 AVG Training Loss:0.218 AVG Test Loss:1.566 AVG Training Acc 98.67 % AVG Test Acc 62.67 %
# Fold 19
# Epoch:1/10 AVG Training Loss:3.352 AVG Test Loss:3.281 AVG Training Acc 11.16 % AVG Test Acc 16.00 %
# Epoch:2/10 AVG Training Loss:3.039 AVG Test Loss:3.020 AVG Training Acc 27.86 % AVG Test Acc 17.33 %
# Epoch:3/10 AVG Training Loss:2.530 AVG Test Loss:2.606 AVG Training Acc 41.33 % AVG Test Acc 30.67 %
# Epoch:4/10 AVG Training Loss:1.928 AVG Test Loss:2.111 AVG Training Acc 65.40 % AVG Test Acc 52.00 %
# Epoch:5/10 AVG Training Loss:1.342 AVG Test Loss:1.664 AVG Training Acc 84.56 % AVG Test Acc 61.33 %
# Epoch:6/10 AVG Training Loss:0.883 AVG Test Loss:1.463 AVG Training Acc 90.95 % AVG Test Acc 68.00 %
# Epoch:7/10 AVG Training Loss:0.582 AVG Test Loss:1.407 AVG Training Acc 94.95 % AVG Test Acc 60.00 %
# Epoch:8/10 AVG Training Loss:0.395 AVG Test Loss:1.436 AVG Training Acc 96.07 % AVG Test Acc 60.00 %
# Epoch:9/10 AVG Training Loss:0.269 AVG Test Loss:1.427 AVG Training Acc 98.53 % AVG Test Acc 64.00 %
# Epoch:10/10 AVG Training Loss:0.190 AVG Test Loss:1.451 AVG Training Acc 99.23 % AVG Test Acc 65.33 %
# Fold 20
# Epoch:1/10 AVG Training Loss:3.355 AVG Test Loss:3.253 AVG Training Acc 11.79 % AVG Test Acc 17.33 %
# Epoch:2/10 AVG Training Loss:3.048 AVG Test Loss:2.829 AVG Training Acc 33.12 % AVG Test Acc 32.00 %
# Epoch:3/10 AVG Training Loss:2.491 AVG Test Loss:2.341 AVG Training Acc 45.89 % AVG Test Acc 44.00 %
# Epoch:4/10 AVG Training Loss:1.867 AVG Test Loss:1.964 AVG Training Acc 61.19 % AVG Test Acc 52.00 %
# Epoch:5/10 AVG Training Loss:1.301 AVG Test Loss:1.693 AVG Training Acc 81.26 % AVG Test Acc 62.67 %
# Epoch:6/10 AVG Training Loss:0.888 AVG Test Loss:1.456 AVG Training Acc 88.84 % AVG Test Acc 61.33 %
# Epoch:7/10 AVG Training Loss:0.626 AVG Test Loss:1.445 AVG Training Acc 91.65 % AVG Test Acc 62.67 %
# Epoch:8/10 AVG Training Loss:0.422 AVG Test Loss:1.274 AVG Training Acc 96.00 % AVG Test Acc 74.67 %
# Epoch:9/10 AVG Training Loss:0.292 AVG Test Loss:1.284 AVG Training Acc 98.32 % AVG Test Acc 66.67 %
# Epoch:10/10 AVG Training Loss:0.210 AVG Test Loss:1.230 AVG Training Acc 98.95 % AVG Test Acc 69.33 %

# %%
trainacc = []
testacc = []
for j in range(num_epochs):
    testsums = []
    trainsums = []
    for i in range(1,k+1):
        testsums.append(foldperf['fold'+str(i)]['test_acc'][j])
        trainsums.append(foldperf['fold'+str(i)]['train_acc'][j])
    trainacc.append(np.mean(trainsums))
    testacc.append(np.mean(testsums))
plt.figure(figsize=(15,15))
plt.plot(np.arange(1,num_epochs+1), trainacc, label='training accuracy')
plt.plot(np.arange(1,num_epochs+1), testacc, label='testing accuracy')
plt.ylabel('mean accuracy % of epoch')
plt.xlabel('epoch')
plt.xticks([0,2,4,6,8,num_epochs])
plt.legend()
plt.xlim((1,num_epochs))
plt.show()
